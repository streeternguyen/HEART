# %% [markdown]
# <a href="https://colab.research.google.com/github/streeternguyen/HEART/blob/master/Copy_Folder_Google_Drive_to_Google_Drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Copy Folder Google Drive to Google Drive - 1TouchPro

# %%
#@title Input
from ipywidgets import widgets

dest_text = widgets.Text(description="Your drive", placeholder='Nhập đường link folder Google Drive của bạn')
source_text = widgets.Text(description="Shared drive", placeholder='Nhập đường link folder Google Drive shared')
from_page_text = widgets.Text(description="Từ trang", value="0")
to_page_text = widgets.Text(description="Đến trang", value="0")
max_download_size_text = widgets.Text(description="Tổng dung lượng tối đa(GB)", value="700")
exclude_str_text = widgets.Text(description="Bỏ file, folder có chứa nội dung", value="")

display(dest_text)
display(source_text)
display(from_page_text)
display(to_page_text)
display(max_download_size_text)
display(exclude_str_text)
# Out:
# Text(value='', description='Your drive', placeholder='Nhập đường link folder Google Drive của bạn')
# Text(value='', description='Shared drive', placeholder='Nhập đường link folder Google Drive shared')
# Text(value='0', description='Từ trang')
# Text(value='0', description='Đến trang')
# Text(value='700', description='Tổng dung lượng tối đa(GB)')
# Text(value='', description='Bỏ file, folder có chứa nội dung')

# %%
#@title Run
import os
import time
import re
import sys
from googleapiclient.discovery import build
from google.colab import auth
from google.colab import drive

class DownloadFromDrive:
    def __init__(self):
        self._total_size = 0
        self._limit_size = 0
        self.excluded_strings = []

    def get_user_credential(self):
        auth.authenticate_user()
        drive_service = build('drive', 'v3')
        return drive_service

    def get_childs_from_folder(self, drive_service, folder_id, from_page, to_page):
        files = []
        page_token = None
        query = f"'{folder_id}' in parents and trashed = false"
        if self.excluded_strings and len(self.excluded_strings) > 0:
            not_contains_query = " and ".join([f"not name contains '{ext}'" for ext in self.excluded_strings])
            query += f" and ({not_contains_query})"

        pages = 0
        while True:
            try:
                pages += 1
                response = drive_service.files().list(q=query,
                                        orderBy='name, createdTime',
                                        fields='files(id, name, mimeType, size), nextPageToken',
                                        pageToken=page_token,
                                        supportsAllDrives=True,
                                        includeItemsFromAllDrives=True).execute()

                if (from_page < pages <= to_page) or to_page == 0:
                    files.extend(response.get('files', []))

                page_token = response.get('nextPageToken', None)
                if page_token is None or  (pages >= to_page > 0):
                    break
            except Exception as e:
                print(f"An error occurred: {str(e)}")
                page_token = None

        print(f"Total files: {len(files)}")
        return files

    def copy_file(self, drive_service, dest_folder_id, source_file):
        if source_file['mimeType'] != 'application/vnd.google-apps.folder':
            body_file_inf = {'parents': [dest_folder_id]}

            if not self.check_if_exists(drive_service, dest_folder_id, source_file['name']):
                try:
                    start_time = time.time()
                    request_copy = drive_service.files().copy(body=body_file_inf, fileId=source_file['id'],
                                                              supportsAllDrives=True).execute()
                    end_time = time.time()

                    fileSize = int(source_file.get('size', 0))
                    size_mb = fileSize / (1024 * 1024)
                    self._total_size += size_mb
                    speed_mb = size_mb / (end_time - start_time)
                    print(f"[{source_file['name']}] copied. Size {size_mb:0.2f} MB. Speed {speed_mb:0.2f} MB/s")


                    if self._total_size >= (self._limit_size * 1024):
                        self.on_total_size_exceeded(f"Total size exceeds {self._limit_size} GB. Ending the program.")
                except Exception as e:
                    print("An error occurred: ", e)
            else:
                print(f"[{source_file['name']}] exists.")
        else:

            source_files = self.get_childs_from_folder(drive_service, source_file['id'], 0, 0)
            if source_files and len(source_files) > 0:
                print(f"Copy at Folder {source_file['name']} Starting")
                sub_folder_id = self.create_folder(drive_service, dest_folder_id, source_file['name'])
                self.copy_multiple_files(drive_service, sub_folder_id, source_files)
                print(f"Copy at Folder {source_file['name']} Ending")


    def create_folder(self, drive_service, dest_folder_id, sub_folder_name):
        sub_folder_inf = {'name': sub_folder_name, 'mimeType': 'application/vnd.google-apps.folder', 'parents': [dest_folder_id]}

        exist_folder_id = self.check_if_exists(drive_service, dest_folder_id, sub_folder_name)
        if not exist_folder_id:
            try:
                folder = drive_service.files().create(body=sub_folder_inf, fields='id').execute()
                return folder['id']
            except Exception as e:
                print("An error occurred: ", e)
        return exist_folder_id


    def check_if_exists(self, drive_service, dest_folder_id, name):
        try:
            processed_name = name.replace("'", "\\'")

            results = drive_service.files().list(q=f"'{dest_folder_id}' in parents and name contains '{processed_name}' and trashed=false",
                                                fields='files(id)').execute()

            if 'files' in results and len(results['files']) > 0:
                return results['files'][0]['id']
        except Exception as e:
            print("An error occurred: ", e)

        return ""


    def copy_multiple_files(self, drive_service, dest_folder_id, source_files):
        for source_file in source_files:
            self.copy_file(drive_service, dest_folder_id, source_file)

    def extract_folder_id_from_url(self, url):
        pattern = r'[-\w]{25,}'
        match = re.search(pattern, url)
        if match:
            return match.group(0)
        else:
            return None

    def on_total_size_exceeded(self, message):
        print(message)
        sys.exit()

    def copy_drive_to_drive(self, destDriveLink, sourceDriveLink, from_page, to_page):
        service = self.get_user_credential()

        start_time = time.time()
        dest_folder_id = self.extract_folder_id_from_url(destDriveLink)
        source_folder_id = self.extract_folder_id_from_url(sourceDriveLink)
        source_folder = service.files().get(fileId=source_folder_id, supportsAllDrives=True).execute()
        new_dest_folder_id = self.create_folder(service, dest_folder_id, source_folder['name'])

        source_files = self.get_childs_from_folder(service, source_folder_id, from_page, to_page)
        self.copy_multiple_files(service, new_dest_folder_id, source_files)
        end_time = time.time()

        size_gb = self._total_size / 1024
        speed_mb = self._total_size / (end_time - start_time)

        print(f"Done. Total Size {size_gb:0.2f} GB. Total Time {int(end_time - start_time)} s. SpeedMB {speed_mb:0.2f} MB/s")


# Main
destDriveLink = dest_text.value
sourceDriveLink = source_text.value
fromPage = int(from_page_text.value)
toPage = int(to_page_text.value)

downloader = DownloadFromDrive()
downloader._limit_size = float(max_download_size_text.value);
downloader.excluded_strings = [ext.strip() for ext in exclude_str_text.value.split(",") if ext.strip()]
downloader.copy_drive_to_drive(destDriveLink, sourceDriveLink, fromPage, toPage)
# Out:
# Total files: 5
# Total files: 81
# Copy at Folder Brighton 1/8/2024 Starting
# [DSCF1471.JPG] copied. Size 2.79 MB. Speed 0.60 MB/s
# [DSCF1478.JPG] copied. Size 2.77 MB. Speed 0.66 MB/s
# [DSCF1479.JPG] copied. Size 3.46 MB. Speed 2.11 MB/s
# [DSCF1486.RAF] copied. Size 53.89 MB. Speed 15.26 MB/s
# [DSCF1486.xmp] copied. Size 0.01 MB. Speed 0.01 MB/s
# [DSCF1489-Enhanced-SR.dng] copied. Size 95.81 MB. Speed 4.25 MB/s
# [DSCF1489.RAF] copied. Size 53.07 MB. Speed 14.10 MB/s
# [DSCF1490.RAF] copied. Size 52.77 MB. Speed 11.52 MB/s
# [DSCF1491.RAF] copied. Size 52.83 MB. Speed 9.30 MB/s
# [DSCF1492.RAF] copied. Size 53.54 MB. Speed 10.70 MB/s
# [DSCF1493.RAF] copied. Size 54.38 MB. Speed 15.78 MB/s
# [DSCF1494.RAF] copied. Size 54.35 MB. Speed 19.00 MB/s
# [DSCF1495.RAF] copied. Size 54.40 MB. Speed 16.73 MB/s
# [DSCF1495.xmp] copied. Size 0.01 MB. Speed 0.00 MB/s
# [DSCF1496.JPG] copied. Size 2.37 MB. Speed 1.59 MB/s
# [DSCF1497.JPG] copied. Size 3.16 MB. Speed 1.64 MB/s
# [DSCF1498.JPG] copied. Size 3.17 MB. Speed 1.75 MB/s
# [DSCF1499.JPG] copied. Size 3.07 MB. Speed 1.43 MB/s
# [DSCF1500.JPG] copied. Size 2.94 MB. Speed 1.61 MB/s
# [DSCF1501.JPG] copied. Size 2.93 MB. Speed 2.02 MB/s
# [DSCF1503.JPG] copied. Size 2.80 MB. Speed 1.70 MB/s
# [DSCF1504.JPG] copied. Size 2.80 MB. Speed 0.73 MB/s
# [DSCF1506.JPG] copied. Size 2.81 MB. Speed 1.61 MB/s
# [DSCF1507.JPG] copied. Size 2.98 MB. Speed 1.77 MB/s
# [DSCF1508.JPG] copied. Size 3.10 MB. Speed 1.78 MB/s
# [DSCF1509.JPG] copied. Size 3.04 MB. Speed 1.78 MB/s
# [DSCF1510.RAF] copied. Size 55.06 MB. Speed 19.29 MB/s
# [DSCF1511.RAF] copied. Size 54.57 MB. Speed 16.77 MB/s
# [DSCF1512.RAF] copied. Size 55.04 MB. Speed 13.21 MB/s
# [DSCF1513.JPG] copied. Size 2.74 MB. Speed 1.85 MB/s
# [DSCF1513.RAF] copied. Size 54.46 MB. Speed 16.28 MB/s
# [DSCF1514.JPG] copied. Size 2.81 MB. Speed 1.72 MB/s
# [DSCF1514.RAF] copied. Size 54.69 MB. Speed 14.28 MB/s
# [DSCF1515.JPG] copied. Size 2.70 MB. Speed 1.53 MB/s
# [DSCF1515.RAF] copied. Size 54.35 MB. Speed 17.74 MB/s
# [DSCF1516.JPG] copied. Size 2.69 MB. Speed 0.77 MB/s
# [DSCF1516.RAF] copied. Size 54.35 MB. Speed 11.62 MB/s
# [DSCF1517.JPG] copied. Size 1.93 MB. Speed 1.07 MB/s
# [DSCF1517.RAF] copied. Size 54.83 MB. Speed 12.05 MB/s
# [DSCF1518.JPG] copied. Size 1.74 MB. Speed 1.16 MB/s
# [DSCF1518.RAF] copied. Size 54.51 MB. Speed 8.81 MB/s
# [DSCF1519.JPG] copied. Size 3.53 MB. Speed 2.10 MB/s
# [DSCF1519.RAF] copied. Size 54.67 MB. Speed 14.14 MB/s
# [DSCF1520.JPG] copied. Size 3.63 MB. Speed 2.53 MB/s
# [DSCF1520.RAF] copied. Size 54.80 MB. Speed 19.34 MB/s
# [DSCF1521.JPG] copied. Size 2.92 MB. Speed 1.50 MB/s
# [DSCF1521.RAF] copied. Size 53.97 MB. Speed 14.01 MB/s
# [DSCF1522.JPG] copied. Size 2.08 MB. Speed 1.12 MB/s
# [DSCF1522.RAF] copied. Size 54.82 MB. Speed 14.92 MB/s
# [DSCF1523.JPG] copied. Size 2.84 MB. Speed 1.59 MB/s
# [DSCF1523.RAF] copied. Size 54.57 MB. Speed 11.00 MB/s
# [DSCF1524.JPG] copied. Size 1.59 MB. Speed 0.84 MB/s
# [DSCF1524.RAF] copied. Size 54.11 MB. Speed 17.98 MB/s
# [DSCF1525.RAF] copied. Size 55.07 MB. Speed 15.78 MB/s
# [DSCF1526.RAF] copied. Size 55.08 MB. Speed 12.99 MB/s
# [DSCF1527.RAF] copied. Size 55.08 MB. Speed 18.04 MB/s
# [DSCF1528.JPG] copied. Size 2.92 MB. Speed 1.74 MB/s
# [DSCF1529.JPG] copied. Size 2.67 MB. Speed 1.55 MB/s
# [DSCF1529.RAF] copied. Size 54.15 MB. Speed 16.23 MB/s
# [DSCF1530.JPG] copied. Size 1.77 MB. Speed 1.09 MB/s
# [DSCF1530.RAF] copied. Size 54.10 MB. Speed 17.54 MB/s
# [DSCF1531.JPG] copied. Size 3.37 MB. Speed 2.63 MB/s
# [DSCF1531.RAF] copied. Size 55.18 MB. Speed 15.55 MB/s
# [DSCF1532.JPG] copied. Size 2.81 MB. Speed 1.81 MB/s
# [DSCF1532.RAF] copied. Size 54.21 MB. Speed 16.74 MB/s
# [DSCF1533.JPG] copied. Size 3.08 MB. Speed 1.69 MB/s
# [DSCF1534.JPG] copied. Size 3.11 MB. Speed 1.76 MB/s
# [DSCF1535.JPG] copied. Size 2.96 MB. Speed 1.46 MB/s
# [DSCF1536.JPG] copied. Size 2.98 MB. Speed 1.87 MB/s
# [DSCF1537.JPG] copied. Size 3.24 MB. Speed 2.10 MB/s
# [DSCF1538.JPG] copied. Size 3.12 MB. Speed 0.83 MB/s
# [DSCF1540.JPG] copied. Size 3.13 MB. Speed 1.74 MB/s
# [DSCF1541.JPG] copied. Size 3.15 MB. Speed 1.63 MB/s
# [DSCF1542.JPG] copied. Size 3.11 MB. Speed 2.18 MB/s
# [DSCF1543.JPG] copied. Size 3.22 MB. Speed 2.05 MB/s
# [DSCF1544.JPG] copied. Size 3.12 MB. Speed 2.03 MB/s
# [DSCF1545.JPG] copied. Size 3.22 MB. Speed 0.88 MB/s
# [DSCF1546.JPG] copied. Size 3.30 MB. Speed 2.24 MB/s
# [DSCF1547.JPG] copied. Size 3.46 MB. Speed 2.60 MB/s
# [DSCF1548.JPG] copied. Size 3.73 MB. Speed 2.24 MB/s
# Total files: 1
# Copy at Folder edited Starting
# [DSCF1495.JPG] copied. Size 13.59 MB. Speed 6.17 MB/s
# Copy at Folder edited Ending
# Copy at Folder Brighton 1/8/2024 Ending
# Total files: 17
# Copy at Folder edited birthday Starting
# [DSCF2526.jpg] copied. Size 19.94 MB. Speed 8.93 MB/s
# [DSCF2529.jpg] copied. Size 22.14 MB. Speed 7.26 MB/s
# [DSCF2533.jpg] copied. Size 19.70 MB. Speed 8.70 MB/s
# [DSCF2544.jpg] copied. Size 20.75 MB. Speed 7.58 MB/s
# [DSCF2569.jpg] copied. Size 19.41 MB. Speed 6.81 MB/s
# [DSCF2571.jpg] copied. Size 22.53 MB. Speed 8.75 MB/s
# [DSCF2598.jpg] copied. Size 20.86 MB. Speed 7.54 MB/s
# [DSCF2605.jpg] copied. Size 18.26 MB. Speed 7.57 MB/s
# [DSCF2616.jpg] copied. Size 18.65 MB. Speed 5.98 MB/s
# [DSCF2625.jpg] copied. Size 19.99 MB. Speed 8.91 MB/s
# [DSCF2635.jpg] copied. Size 21.98 MB. Speed 9.03 MB/s
# [DSCF2648.jpg] copied. Size 18.31 MB. Speed 7.10 MB/s
# [DSCF2657.jpg] copied. Size 6.95 MB. Speed 2.87 MB/s
# [DSCF2661.jpg] copied. Size 8.34 MB. Speed 3.91 MB/s
# [DSCF2682.jpg] copied. Size 19.26 MB. Speed 6.96 MB/s
# [DSCF2693.jpg] copied. Size 18.61 MB. Speed 8.15 MB/s
# [DSCF2694.jpg] copied. Size 23.59 MB. Speed 10.91 MB/s
# Copy at Folder edited birthday Ending
# Total files: 2
# Copy at Folder Fujifilm Starting
# Total files: 430
# Copy at Folder 121_FUJI Starting
# [DSCF1563.JPG] copied. Size 3.42 MB. Speed 2.27 MB/s
# [DSCF1565.JPG] copied. Size 3.42 MB. Speed 1.76 MB/s
# [DSCF1566.JPG] copied. Size 3.43 MB. Speed 2.34 MB/s
# [DSCF1567.JPG] copied. Size 2.74 MB. Speed 1.87 MB/s
# [DSCF1568.JPG] copied. Size 3.12 MB. Speed 0.88 MB/s
# [DSCF1569.JPG] copied. Size 3.11 MB. Speed 2.05 MB/s
# [DSCF1570.JPG] copied. Size 3.13 MB. Speed 1.92 MB/s
# [DSCF1571.JPG] copied. Size 3.02 MB. Speed 1.75 MB/s
# [DSCF1572.JPG] copied. Size 2.59 MB. Speed 1.45 MB/s
# [DSCF1573.JPG] copied. Size 2.76 MB. Speed 1.93 MB/s
# [DSCF1576.JPG] copied. Size 2.90 MB. Speed 1.69 MB/s
# [DSCF1577.JPG] copied. Size 3.22 MB. Speed 2.42 MB/s
# [DSCF1578.JPG] copied. Size 3.24 MB. Speed 2.04 MB/s
# [DSCF1579.JPG] copied. Size 3.01 MB. Speed 1.97 MB/s
# [DSCF1580.JPG] copied. Size 2.75 MB. Speed 1.48 MB/s
# [DSCF1581.JPG] copied. Size 2.68 MB. Speed 1.63 MB/s
# [DSCF1582.JPG] copied. Size 3.31 MB. Speed 2.15 MB/s
# [DSCF1583.JPG] copied. Size 2.93 MB. Speed 1.62 MB/s
# [DSCF1584.JPG] copied. Size 0.35 MB. Speed 0.20 MB/s
# [DSCF1585.JPG] copied. Size 0.32 MB. Speed 0.19 MB/s
# [DSCF1586.JPG] copied. Size 3.31 MB. Speed 1.95 MB/s
# [DSCF1587.JPG] copied. Size 3.20 MB. Speed 1.49 MB/s
# [DSCF1588.JPG] copied. Size 3.41 MB. Speed 1.95 MB/s
# [DSCF1589.JPG] copied. Size 3.33 MB. Speed 1.91 MB/s
# [DSCF1590.JPG] copied. Size 3.29 MB. Speed 2.09 MB/s
# [DSCF1591.JPG] copied. Size 3.35 MB. Speed 2.13 MB/s
# [DSCF1592.JPG] copied. Size 3.32 MB. Speed 1.49 MB/s
# [DSCF1593.JPG] copied. Size 3.34 MB. Speed 2.76 MB/s
# [DSCF1594.JPG] copied. Size 3.02 MB. Speed 1.61 MB/s
# [DSCF1595.JPG] copied. Size 2.96 MB. Speed 1.89 MB/s
# [DSCF1596.JPG] copied. Size 2.98 MB. Speed 2.09 MB/s
# [DSCF1597.JPG] copied. Size 3.00 MB. Speed 1.78 MB/s
# [DSCF1598.JPG] copied. Size 3.06 MB. Speed 1.68 MB/s
# [DSCF1599.JPG] copied. Size 2.76 MB. Speed 2.17 MB/s
# [DSCF1600.JPG] copied. Size 2.67 MB. Speed 0.75 MB/s
# [DSCF1601.JPG] copied. Size 2.87 MB. Speed 1.95 MB/s
# [DSCF1602.JPG] copied. Size 2.79 MB. Speed 1.83 MB/s
# [DSCF1603.JPG] copied. Size 2.98 MB. Speed 0.79 MB/s
# [DSCF1604.MOV] copied. Size 186.33 MB. Speed 164.93 MB/s
# [DSCF1605.MOV] copied. Size 25.82 MB. Speed 23.55 MB/s
# [DSCF1606.MOV] copied. Size 323.58 MB. Speed 307.29 MB/s
# [DSCF1607.JPG] copied. Size 3.14 MB. Speed 1.91 MB/s
# [DSCF1608.JPG] copied. Size 2.67 MB. Speed 1.39 MB/s
# [DSCF1609.JPG] copied. Size 2.80 MB. Speed 1.77 MB/s
# [DSCF1610.JPG] copied. Size 3.02 MB. Speed 2.07 MB/s
# [DSCF1611.JPG] copied. Size 2.79 MB. Speed 1.83 MB/s
# [DSCF1612.JPG] copied. Size 2.73 MB. Speed 1.46 MB/s
# [DSCF1613.JPG] copied. Size 3.02 MB. Speed 1.65 MB/s
# [DSCF1614.JPG] copied. Size 2.88 MB. Speed 1.57 MB/s
# [DSCF1615.JPG] copied. Size 3.04 MB. Speed 1.93 MB/s
# [DSCF1616.JPG] copied. Size 2.85 MB. Speed 1.52 MB/s
# [DSCF1617.JPG] copied. Size 2.82 MB. Speed 1.77 MB/s
# [DSCF1618.JPG] copied. Size 2.87 MB. Speed 1.83 MB/s
# [DSCF1619.JPG] copied. Size 2.90 MB. Speed 1.85 MB/s
# [DSCF1620.JPG] copied. Size 2.93 MB. Speed 0.79 MB/s
# [DSCF1621.JPG] copied. Size 3.14 MB. Speed 1.77 MB/s
# [DSCF1622.JPG] copied. Size 2.74 MB. Speed 1.50 MB/s
# [DSCF1623.JPG] copied. Size 2.69 MB. Speed 1.57 MB/s
# [DSCF1624.JPG] copied. Size 3.05 MB. Speed 1.88 MB/s
# [DSCF1625.JPG] copied. Size 2.79 MB. Speed 1.44 MB/s
# [DSCF1626.JPG] copied. Size 2.87 MB. Speed 2.10 MB/s
# [DSCF1627.JPG] copied. Size 2.76 MB. Speed 1.41 MB/s
# [DSCF1628.JPG] copied. Size 2.83 MB. Speed 1.49 MB/s
# [DSCF1629.JPG] copied. Size 2.83 MB. Speed 1.62 MB/s
# [DSCF1630.JPG] copied. Size 3.00 MB. Speed 1.67 MB/s
# [DSCF1631.JPG] copied. Size 2.24 MB. Speed 1.36 MB/s
# [DSCF1632.JPG] copied. Size 3.04 MB. Speed 1.87 MB/s
# [DSCF1633.JPG] copied. Size 3.24 MB. Speed 1.91 MB/s
# [DSCF1634.JPG] copied. Size 2.53 MB. Speed 1.09 MB/s
# [DSCF1635.JPG] copied. Size 3.06 MB. Speed 1.23 MB/s
# [DSCF1636.JPG] copied. Size 2.93 MB. Speed 1.69 MB/s
# [DSCF1637.JPG] copied. Size 2.79 MB. Speed 1.77 MB/s
# [DSCF1638.JPG] copied. Size 2.68 MB. Speed 1.32 MB/s
# [DSCF1639.JPG] copied. Size 2.88 MB. Speed 1.26 MB/s
# [DSCF1640.JPG] copied. Size 2.98 MB. Speed 1.58 MB/s
# [DSCF1641.JPG] copied. Size 2.68 MB. Speed 1.66 MB/s
# [DSCF1642.JPG] copied. Size 2.73 MB. Speed 1.75 MB/s
# [DSCF1643.JPG] copied. Size 2.72 MB. Speed 1.79 MB/s
# [DSCF1644.JPG] copied. Size 2.70 MB. Speed 1.22 MB/s
# [DSCF1645.JPG] copied. Size 2.72 MB. Speed 1.52 MB/s
# [DSCF1646.JPG] copied. Size 2.76 MB. Speed 1.55 MB/s
# [DSCF1647.JPG] copied. Size 2.95 MB. Speed 1.88 MB/s
# [DSCF1648.JPG] copied. Size 2.89 MB. Speed 1.48 MB/s
# [DSCF1649.JPG] copied. Size 2.67 MB. Speed 1.48 MB/s
# [DSCF1650.JPG] copied. Size 3.06 MB. Speed 1.89 MB/s
# [DSCF1651.JPG] copied. Size 3.12 MB. Speed 1.71 MB/s
# [DSCF1652.JPG] copied. Size 2.91 MB. Speed 1.90 MB/s
# [DSCF1653.JPG] copied. Size 2.97 MB. Speed 1.83 MB/s
# [DSCF1654.JPG] copied. Size 2.94 MB. Speed 1.69 MB/s
# [DSCF1655.JPG] copied. Size 2.68 MB. Speed 1.34 MB/s
# [DSCF1656.JPG] copied. Size 2.83 MB. Speed 1.91 MB/s
# [DSCF1657.JPG] copied. Size 2.79 MB. Speed 1.70 MB/s
# [DSCF1658.JPG] copied. Size 2.74 MB. Speed 1.65 MB/s
# [DSCF1659.JPG] copied. Size 2.86 MB. Speed 1.56 MB/s
# [DSCF1660.JPG] copied. Size 2.84 MB. Speed 1.73 MB/s
# [DSCF1661.JPG] copied. Size 2.79 MB. Speed 1.62 MB/s
# [DSCF1662.JPG] copied. Size 2.95 MB. Speed 1.73 MB/s
# [DSCF1663.JPG] copied. Size 2.97 MB. Speed 1.47 MB/s
# [DSCF1664.JPG] copied. Size 2.68 MB. Speed 1.48 MB/s
# [DSCF1665.JPG] copied. Size 2.94 MB. Speed 1.83 MB/s
# [DSCF1666.JPG] copied. Size 2.59 MB. Speed 1.56 MB/s
# [DSCF1667.JPG] copied. Size 2.58 MB. Speed 1.88 MB/s
# [DSCF1668.JPG] copied. Size 3.23 MB. Speed 0.84 MB/s
# [DSCF1669.JPG] copied. Size 2.80 MB. Speed 1.83 MB/s
# [DSCF1670.JPG] copied. Size 2.84 MB. Speed 1.68 MB/s
# [DSCF1671.JPG] copied. Size 2.61 MB. Speed 1.75 MB/s
# [DSCF1672.JPG] copied. Size 3.12 MB. Speed 1.85 MB/s
# [DSCF1673.JPG] copied. Size 3.12 MB. Speed 2.06 MB/s
# [DSCF1674.JPG] copied. Size 3.10 MB. Speed 2.19 MB/s
# [DSCF1675.JPG] copied. Size 3.08 MB. Speed 1.83 MB/s
# [DSCF1676.JPG] copied. Size 2.92 MB. Speed 2.09 MB/s
# [DSCF1677.JPG] copied. Size 2.73 MB. Speed 1.47 MB/s
# [DSCF1678.JPG] copied. Size 3.07 MB. Speed 1.93 MB/s
# [DSCF1679.JPG] copied. Size 3.07 MB. Speed 1.93 MB/s
# [DSCF1680.JPG] copied. Size 2.58 MB. Speed 1.49 MB/s
# [DSCF1681.JPG] copied. Size 2.69 MB. Speed 1.55 MB/s
# [DSCF1682.JPG] copied. Size 2.79 MB. Speed 1.83 MB/s
# [DSCF1683.JPG] copied. Size 2.87 MB. Speed 1.57 MB/s
# [DSCF1684.JPG] copied. Size 2.25 MB. Speed 1.40 MB/s
# [DSCF1685.JPG] copied. Size 2.84 MB. Speed 1.52 MB/s
# [DSCF1686.JPG] copied. Size 2.57 MB. Speed 1.82 MB/s
# [DSCF1687.JPG] copied. Size 2.76 MB. Speed 1.69 MB/s
# [DSCF1688.JPG] copied. Size 2.62 MB. Speed 1.48 MB/s
# [DSCF1689.JPG] copied. Size 2.93 MB. Speed 2.43 MB/s
# [DSCF1690.JPG] copied. Size 2.74 MB. Speed 1.35 MB/s
# [DSCF1691.JPG] copied. Size 2.87 MB. Speed 1.60 MB/s
# [DSCF1692.JPG] copied. Size 3.23 MB. Speed 1.95 MB/s
# [DSCF1693.JPG] copied. Size 2.93 MB. Speed 1.62 MB/s
# [DSCF1694.JPG] copied. Size 2.55 MB. Speed 1.58 MB/s
# [DSCF1695.JPG] copied. Size 2.71 MB. Speed 1.59 MB/s
# [DSCF1696.JPG] copied. Size 2.76 MB. Speed 1.65 MB/s
# [DSCF1697.JPG] copied. Size 2.82 MB. Speed 1.88 MB/s
# [DSCF1698.JPG] copied. Size 3.54 MB. Speed 2.26 MB/s
# [DSCF1699.JPG] copied. Size 3.31 MB. Speed 2.13 MB/s
# [DSCF1700.JPG] copied. Size 3.16 MB. Speed 1.87 MB/s
# [DSCF1701.JPG] copied. Size 3.37 MB. Speed 2.30 MB/s
# [DSCF1702.JPG] copied. Size 3.41 MB. Speed 1.82 MB/s
# [DSCF1703.JPG] copied. Size 3.49 MB. Speed 2.02 MB/s
# [DSCF1704.JPG] copied. Size 3.31 MB. Speed 1.74 MB/s
# [DSCF1705.JPG] copied. Size 3.20 MB. Speed 1.96 MB/s
# [DSCF1706.JPG] copied. Size 3.16 MB. Speed 0.85 MB/s
# [DSCF1707.JPG] copied. Size 3.13 MB. Speed 1.76 MB/s
# [DSCF1708.JPG] copied. Size 3.05 MB. Speed 1.95 MB/s
# [DSCF1709.JPG] copied. Size 3.18 MB. Speed 1.90 MB/s
# [DSCF1710.JPG] copied. Size 3.02 MB. Speed 1.84 MB/s
# [DSCF1711.JPG] copied. Size 2.99 MB. Speed 1.53 MB/s
# [DSCF1712.JPG] copied. Size 2.99 MB. Speed 2.18 MB/s
# [DSCF1713.JPG] copied. Size 3.13 MB. Speed 1.58 MB/s
# [DSCF1714.JPG] copied. Size 3.22 MB. Speed 1.81 MB/s
# [DSCF1715.JPG] copied. Size 3.11 MB. Speed 2.02 MB/s
# [DSCF1716.JPG] copied. Size 3.25 MB. Speed 1.83 MB/s
# [DSCF1717.JPG] copied. Size 2.64 MB. Speed 1.62 MB/s
# [DSCF1718.JPG] copied. Size 2.84 MB. Speed 1.91 MB/s
# [DSCF1719.JPG] copied. Size 3.09 MB. Speed 1.71 MB/s
# [DSCF1720.JPG] copied. Size 3.06 MB. Speed 2.08 MB/s
# [DSCF1721.JPG] copied. Size 3.01 MB. Speed 1.64 MB/s
# [DSCF1722.JPG] copied. Size 3.09 MB. Speed 1.71 MB/s
# [DSCF1723.JPG] copied. Size 2.92 MB. Speed 1.56 MB/s
# [DSCF1724.JPG] copied. Size 2.90 MB. Speed 1.72 MB/s
# [DSCF1725.JPG] copied. Size 2.79 MB. Speed 1.74 MB/s
# [DSCF1726.JPG] copied. Size 3.01 MB. Speed 1.64 MB/s
# [DSCF1727.JPG] copied. Size 3.14 MB. Speed 2.21 MB/s
# [DSCF1728.JPG] copied. Size 3.25 MB. Speed 1.92 MB/s
# [DSCF1729.JPG] copied. Size 3.30 MB. Speed 2.27 MB/s
# [DSCF1730.JPG] copied. Size 3.25 MB. Speed 2.16 MB/s
# [DSCF1731.JPG] copied. Size 3.40 MB. Speed 2.12 MB/s
# [DSCF1732.JPG] copied. Size 3.13 MB. Speed 2.17 MB/s
# [DSCF1733.JPG] copied. Size 3.21 MB. Speed 1.67 MB/s
# [DSCF1734.JPG] copied. Size 3.19 MB. Speed 1.53 MB/s
